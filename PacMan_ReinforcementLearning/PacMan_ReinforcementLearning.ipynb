# %%
# !pip install gym
# !pip install Keras
# !pip install numpy
# !pip install opencv-python
# !pip install pyglet==1.2.4

# %%
import warnings
warnings.filterwarnings('ignore')

# !python main.py -n DDQN -m TEST -l saved.h5 -s ournet.h5
